# %%
from PLBenchmarks import targets, edges
from IPython.core.display import HTML

# %% [markdown]
# # Get a HTML table of the edges
# calculated for one target.
# The available targets can be found via
# `[t['name'] for t in targets.target_list]`.

# %%
HTML(edges.getEdgesSetHTML('jnk1'))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>Mol1</th>
#       <th>Mol2</th>
#       <th>exp. DeltaG [kcal/mol]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17124-1</td>
#       <td>18634-1</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#       <td>-0.32</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18626-1</td>
#       <td>18624-1</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18636-1</td>
#       <td>18625-1</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/></td>
#       <td>-0.60</td>
# ...

# %% [markdown]
# # Get a graph representation of the ligands and calculated edges

# %%
tgt = targets.target('jnk1')
graph = tgt.getGraph()
# Out:
# /opt/anaconda3/envs/off-demo/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

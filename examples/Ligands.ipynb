# %%
from PLBenchmarks import ligands
from IPython.core.display import HTML

# %%
HTML(ligands.ligandSet().getHTML('cdk2', ['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-9e1424a6a46b> in <module>
# ----> 1 HTML(ligands.ligandSet().getHTML('cdk2', ['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
#
# TypeError: __init__() missing 1 required positional argument: 'target'

# %%
HTML(ligands.getLigandSetHTML('pde2', ['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="4" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>pic50</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_pic50</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_43249674</td>
#       <td>8.57 dimensionless</td>
#       <td>10.1038/s41598-018-23039-5</td>
#       <td>table 1 cmpd 2</td>
#       <td>0.15 dimensionless</td>
#       <td>-11.764156387907459 kcal/mol</td>
#       <td>-0.205907054630819 kcal/mol</td>
#       <td><a target="_blank" href="http://dx.doi.org/10.1038/s41598-018-23039-5">Pérez-Benito et al., Sci Rep 2018</a></td>
# ...

# %%
HTML(ligands.getLigandSetHTML('thrombin', ['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="8" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>dg</th>
#       <th>dh</th>
#       <th>tds</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_dg</th>
#       <th>e_dh</th>
#       <th>e_tds</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_1a</td>
#       <td>-31.3 kJ/mol</td>
#       <td>-13.1 kJ/mol</td>
#       <td>-18.2 kJ/mol</td>
#       <td>10.1016/j.jmb.2009.04.051</td>
#       <td>Table 1 cmpd 1a</td>
#       <td>0.2 kJ/mol</td>
#       <td>0.9 kJ/mol</td>
#       <td>0.7 kJ/mol</td>
#       <td>-7.480879541108987 kcal/mol</td>
# ...

# %%
HTML(ligands.getLigandSetHTML('ptp1b', ['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="4" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ki</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_ki</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_20667_2qbp</td>
#       <td>0.004 uM</td>
#       <td>10.1021/jm0702478</td>
#       <td>Table 3, entry 32</td>
#       <td>0.0 uM</td>
#       <td>-11.527967281013156 kcal/mol</td>
#       <td>0.0 kcal/mol</td>
#       <td><a target="_blank" href="http://dx.doi.org/10.1021/jm0702478">Wilson et al., J. Med. Chem. 2007</a></td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/>
# dtype: object</td>
# ...

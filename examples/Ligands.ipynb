# %%
from PLBenchmarks import ligands
from IPython.core.display import HTML

# %%
HTML(ligands.ligandSet('cdk2').getHTML(columns=['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="4" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ic50</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_ic50</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_17</td>
#       <td>6.8 uM</td>
#       <td>10.1021/jm0311442</td>
#       <td>Table 2, entry 17</td>
#       <td>4.8 uM</td>
#       <td>-7.09348579743778 kcal/mol</td>
#       <td>-7.301133007359014 kcal/mol</td>
#       <td>REP1http://dx.doi.org/10.1021/jm0311442REP2Hardcastle et al., J. Med. Chem. 2004REP3</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/>
# dtype: object</td>
# ...

# %%
HTML(ligands.ligandSet('cdk2').getHTML(columns=['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="4" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ic50</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_ic50</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_17</td>
#       <td>6.8 uM</td>
#       <td>10.1021/jm0311442</td>
#       <td>Table 2, entry 17</td>
#       <td>4.8 uM</td>
#       <td>-7.09348579743778 kcal/mol</td>
#       <td>-7.301133007359014 kcal/mol</td>
#       <td>REP1http://dx.doi.org/10.1021/jm0311442REP2Hardcastle et al., J. Med. Chem. 2004REP3</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/>
# dtype: object</td>
# ...

# %%
HTML(ligands.getLigandSetHTML('thrombin', ['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="8" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>dg</th>
#       <th>dh</th>
#       <th>tds</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_dg</th>
#       <th>e_dh</th>
#       <th>e_tds</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_1a</td>
#       <td>-31.3 kJ/mol</td>
#       <td>-13.1 kJ/mol</td>
#       <td>-18.2 kJ/mol</td>
#       <td>10.1016/j.jmb.2009.04.051</td>
#       <td>Table 1 cmpd 1a</td>
#       <td>0.2 kJ/mol</td>
#       <td>0.9 kJ/mol</td>
#       <td>0.7 kJ/mol</td>
#       <td>-7.480879541108987 kcal/mol</td>
# ...

# %%
HTML(ligands.ligandSet('ptp1b').getHTML(columns=['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="4" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>measurement</th>
#       <th>ROMol</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ki</th>
#       <th>doi</th>
#       <th>comment</th>
#       <th>e_ki</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th>doi_html</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_20667_2qbp</td>
#       <td>0.004 uM</td>
#       <td>10.1021/jm0702478</td>
#       <td>Table 3, entry 32</td>
#       <td>0.0 uM</td>
#       <td>-11.527967281013156 kcal/mol</td>
#       <td>0.0 kcal/mol</td>
#       <td>REP1http://dx.doi.org/10.1021/jm0702478REP2Wilson et al., J. Med. Chem. 2007REP3</td>
#       <td><img src="data:image/png;base64,..." alt="Mol"/>
# dtype: object</td>
#     </tr>
# ...

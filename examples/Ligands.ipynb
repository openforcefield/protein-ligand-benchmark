# %%
from plbenchmark import ligands
from IPython.core.display import HTML
# Out:
# _ColormakerRegistry()
# {'mcl1_sample': {'name': 'mcl1_sample', 'date': datetime.date(2020, 8, 26), 'dir': '2020-08-26_mcl1_sample'}}

# %%
HTML(ligands.LigandSet('mcl1_sample').get_html(columns=['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th colspan="3" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#       <th>ROMol</th>
#       <th>measurement</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>ki</th>
#       <th>comment</th>
#       <th>e_ki</th>
#       <th>dg</th>
#       <th>e_dg</th>
#       <th></th>
#       <th>Reference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_23</td>
#       <td>0.37 micromolar</td>
#       <td>Table 2, entry 23</td>
#       <td>0.03 micromolar</td>
#       <td>-8.83 kilocalorie / mole</td>
#       <td>0.05 kilocalorie / mole</td>
#       <td>&lt;img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/&gt;
# dtype: object</td>
#       <td><a target="_blank" href="http://dx.doi.org/10.1021/jm301448p">Friberg et al., J. Med. Chem. 2013</a></td>
# ...

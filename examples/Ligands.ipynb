# %%
from PLBenchmarks import ligands
from IPython.core.display import HTML

# %%
HTML(ligands.ligandSet('mcl1').getHTML(columns=['name', 'ROMol', 'measurement', 'DerivedMeasurement']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th>name</th>
#       <th>ROMol</th>
#       <th colspan="4" halign="left">measurement</th>
#       <th colspan="2" halign="left">DerivedMeasurement</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>ki</th>
#       <th>comment</th>
#       <th>e_ki</th>
#       <th>Reference</th>
#       <th>dg</th>
#       <th>e_dg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lig_23</td>
#       <td>&lt;img data-content="rdkit/molecule" src="data:image/png;base64,..." alt="Mol"/&gt;
# dtype: object</td>
#       <td>0.37 micromolar</td>
#       <td>Table 2, entry 23</td>
#       <td>0.03 micromolar</td>
#       <td><a target="_blank" href="http://dx.doi.org/10.1021/jm301448p">Friberg et al., J. Med. Chem. 2013</a></td>
#       <td>-8.83 kilocalorie / mole</td>
#       <td>0.05 kilocalorie / mole</td>
#     </tr>
#     <tr>
# ...
